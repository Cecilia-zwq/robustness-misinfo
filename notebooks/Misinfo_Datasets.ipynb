# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("ComplexDataLab/Misinfo_Datasets", "default")
# Out:
# Generating train split:   0%|          | 0/1218778 [00:01<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from datasets import load_dataset
#       3 # Login using e.g. `huggingface-cli login` to access this dataset
# ----> 4 ds = load_dataset("ComplexDataLab/Misinfo_Datasets", "default")
#
# File ~/miniconda3/envs/misinfo/lib/python3.11/site-packages/datasets/load.py:1708, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1705     return builder_instance.as_streaming_dataset(split=split)
#    1707 # Download and prepare data
# -> 1708 builder_instance.download_and_prepare(
#    1709     download_config=download_config,
# ...
